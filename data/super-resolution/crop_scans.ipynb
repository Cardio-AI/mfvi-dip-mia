# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
img = np.load('lgg/BraTS19_TCIA10_109_1_t2.npy')
print(img.shape)
img = img[32:-32,32:-32]
plt.imshow(img)
# Out:
# (256, 256)

# %%
np.save('lgg/BraTS19_TCIA10_109_1_t2.npy', img)
