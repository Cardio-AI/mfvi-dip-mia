# %%
# %matplotlib notebook
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm
from pathlib import Path
import itertools
import numpy as np
import torch
import time
from tqdm import tqdm
import seaborn as sns

# %%
run = np.load("/opt/laves/bo_results/4_fig_data.npz", allow_pickle=True)

# %%
XX_lr = run['XX_lr']
XX_wd = run['XX_wd']
pred = run['pred']
X = run['observed_X']
acq = run['acq']
confidence = run['confidence']

# %%
X
# Out:
# array([[4.00000000e-08, 1.00000000e-02],
#        [4.00000000e-06, 1.00000000e-01],
#        [4.00000000e-06, 1.00000000e-02],
#        [4.00000000e-08, 1.00000000e-01],
#        [1.00000000e-04, 8.90215085e-02],
#        [7.45476747e-07, 3.21606638e-02],
#        [1.74752840e-08, 5.33669923e-04],
#        [1.00000000e-08, 1.26185688e-02],
#        [1.00000000e-08, 5.85702082e-04]])

# %%
pred*40
# Out:
# array([[25.62991212, 25.62991617, 25.6299201 , ..., 25.62972122,
#         25.62971355, 25.62970579],
#        [25.62990032, 25.62990431, 25.62990819, ..., 25.62970652,
#         25.62969885, 25.62969109],
#        [25.62988829, 25.62989223, 25.62989605, ..., 25.62969159,
#         25.62968392, 25.62967616],
#        ...,
#        [25.62799087, 25.62798807, 25.62798521, ..., 25.62753628,
#         25.62753069, 25.6275251 ],
#        [25.62796707, 25.62796419, 25.62796127, ..., 25.62751052,
#         25.62750496, 25.62749941],
#        [25.62794328, 25.62794033, 25.62793734, ..., 25.62748479,
#         25.62747928, 25.62747377]])

# %%
fig4, ax4 = plt.subplots(subplot_kw={"projection": "3d"})
ln41 = ax4.plot_surface(np.log10(XX_lr),
                        np.log10(XX_wd),
                        pred*40,
                        cmap=cm.jet,
                        linewidth=0, antialiased=False)
fig4.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
